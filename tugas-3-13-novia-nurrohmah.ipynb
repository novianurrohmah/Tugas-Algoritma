# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
tantangan = 1
while tantangan < 7:
    print("Tantangan ke " + str(tantangan))
    tantangan += 1
# Out:
# Tantangan ke 1
# Tantangan ke 2
# Tantangan ke 3
# Tantangan ke 4
# Tantangan ke 5
# Tantangan ke 6

# %%
n = int(input("Masukkan nilai n: "))
total = 0
a = 1

while a <= n:
    total += a
    a += 1

print("Total penjumlahan dari 1 hingga", n, "adalah", total)
# Out:
# Masukkan nilai n:  5
# Total penjumlahan dari 1 hingga 5 adalah 15

# %%
hari_ini = input("Masukkan hari = ")

if hari_ini.upper() == 'SENIN':
    jadwal = '08.30 - 11.10  Statistika Dasar, 11.10 - 13.00  Struktur Aljabar'
    
elif hari_ini.upper() == 'SELASA':
    jadwal = '09.00 - 11.10  Kalkulus II, 11.10 - 13.50  Aljabar Linear Elementer'

elif hari_ini.upper() == 'RABU':
    jadwal = '11.10 - 13.00  Algoritma dan Srtuktur Data, 17.00 - SELESAI  Pendidikan Agama Islam'
    
elif hari_ini.upper() == 'KAMIS':
    jadwal = '08.30 - 11.10  Geometri Analitik, 11.40 - 12.40  Tutorial Struktur Aljabar'

elif hari_ini.upper() == 'JUMAT':
    jadwal ='Tidak ada kelas'

elif hari_ini.upper() == 'SABTU':
    jadwal = 'Tidak ada kelas'
    
elif hari_ini.upper() == 'MINGGU':
    jadwal = 'Libur'

else:
    jadwal = 'Jadwal tidak diketahui.'
    
print("Hari ini adalah",hari_ini)
print(f"Jadwal kuliah hari ini adalah {jadwal}")
# Out:
# Masukkan hari =  Rabu
# Hari ini adalah Rabu
# Jadwal kuliah hari ini adalah 11.10 - 13.00  Algoritma dan Srtuktur Data,17.00 - SELESAI  Pendidikan Agama Islam

# %%
umur = float(input("Berapa umur anda?"))
if umur >= 60:
    print("Anda sudah lanjut usia")
elif umur >= 44:
    print("Anda sudah pra lanjut usia")
elif umur >= 19:
    print("Anda sudah dewasa")
elif umur >= 10:
    print("Anda sudah remaja")
elif umur >= 5:
    print("Anda masih anak anak")
elif umur >= 1:
    print("Anda masih balita")
else: 
    print("Anda masih bayi")
# Out:
# Berapa umur anda? 54
# Anda sudah pra lanjut usia

# %%
umur = float(input("Berapa umur anda?"))
if umur <= 5:
    print("Anda masih balita")
elif umur <= 10:
    print("Anda masih anak anak")
elif umur <= 19:
    print("Anda sudah remaja")
elif umur <= 44:
    print("Anda sudah dewasa")
elif umur <= 60:
    print("Anda sudah pra lanjut usia") 
else: 
    print("Anda sudah lanjut usia")
# Out:
# Berapa umur anda? 61
# Anda sudah lanjut usia
