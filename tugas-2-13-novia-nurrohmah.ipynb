# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
nama = "Novia Nurrohmah"
nim = 2308541013
prodi = "Matematika"
angkatan = 2023

print(f"perkenalkan saya {nama} dengan nim {nim} dari prodi {prodi} angkatan {angkatan}")
# Out:
# perkenalkan saya Novia Nurrohmah dengan nim 2308541013 dari prodi Matematika angkatan 2023

# %%
jumlah_barang = 10
harga_barang = 50000
total_harga = jumlah_barang * harga_barang

print(f"Anda memesan {jumlah_barang} barang dengan harga {harga_barang} per barang. Total harga yang harus dibayar adalah {total_harga}."
)
# Out:
# Anda memesan 10 barang dengan harga 50000 per barang. Total harga yang harus dibayar adalah 500000.

# %%
harga_barang = 150000
diskon = 0.15

print(f"Harga barang setelah diskon {diskon*100}% adalah Rp {harga_barang - (harga_barang * diskon):,}"
)
# Out:
# Harga barang setelah diskon 15.0% adalah Rp 127,500.0

# %%
angka1 = 10
angka2 = 5
angka3 = 2

total = angka1 + angka2 + angka3
print("Jumlah total:", total)

# %%
print(5+2)
print(1-9)
print(9*2)
print(9/4)
print(9//4)
print(9%4)
print(4**2)
x=6
x+=2
print(x)
x-=4
print(x)
x*=2
print(x)
# Out:
# 7
# -8
# 18
# 2.25
# 2
# 1
# 16
# 8
# 4
# 8

# %%
pesan = "jangan lupa makan"
print(pesan[0:6])
print(pesan[0:-5])
print(pesan[3:-2])
print(pesan[1:-1:3])
print(pesan[:-3])
print(pesan[2:])
print(pesan[:])
# Out:
# jangan
# jangan lupa
# gan lupa mak
# aalaa
# jangan lupa ma
# ngan lupa makan
# jangan lupa makan

# %%
kalimat = "Matematika Ilmu yang Mematikan"
print(len(kalimat))
kalimat.upper()
# Out:
# 30
# 'MATEMATIKA ILMU YANG MEMATIKAN'

# %%
kalimat.lower()
# Out:
# 'matematika ilmu yang mematikan'

# %%
kalimat.find("Ilmu")
# Out:
# 11

# %%
kalimat.find("yang")
# Out:
# 16

# %%
kalimat.replace("Mematikan","Menyenangkan")
# Out:
# 'Matematika Ilmu yang Menyenangkan'

# %%
kalimat.replace("Menyenangkan","mematikan")
# Out:
# 'Matematika Ilmu yang Mematikan'

# %%
print("Matematika" in kalimat)
# Out:
# True

# %%
print("ilmu" in kalimat)
# Out:
# False

# %%
a=245>178
print(a)

a=245<178
print(a)

a=560>=300
print(a)

a=560<=300
print(a)

a=450==450
print(a)

a=400==500
print(a)

a=5!=25
print(a)

a=5!=5
print(a)
# Out:
# True
# False
# True
# False
# True
# False
# True
# False

# %%
pensil = 25
pena = 30
print(pensil < 30 and pena > 10)
print(pensil > 10 or pena < 10)
print(pensil > 30 or pena <10)
print(not(pensil > 30 or pena <10))
# Out:
# True
# True
# False
# True
