# %%
#Membuat code untuk persamaan kuadrat
#input berupa a,b,c berdasarkan rumus umum ax^2+bx+c=0
#1. Mencari solusi menggunakan diskriminan
#2. Menampilkan grafik persamaan kuadrat yang dihasilkan
#3. Menerima input berupa akar-akar yang diketahui dan mencari tahu persamaan yang dihasilkan
#4. Menentukan titik puncak dan sumbu simetri

# %%
import numpy as np
import matplotlib.pyplot as plt
import cmath

# Menentukan persamaan kuadrat dari akar-akarnya
a_13 = 1
akar1_13 = 2
akar2_13 = -3
b_13 = -(akar1_13 + akar2_13)
c_13 = akar1_13 * akar2_13
persamaan_kuadrat_13 = f"{a_13}x^2 + {b_13}x + {c_13}"

# Menampilkan persamaan kuadrat
print("Persamaan Kuadrat:", persamaan_kuadrat_13)

# Menentukan grafik fungsi kuadrat
x_13 = np.linspace(-10, 10, 100)
y_13 = a_13 * x**2 + b_13 * x + c_13

plt.figure(figsize=(8, 6))
plt.plot(x_13, y_13, b_13, label='Persamaan Kuadrat')

# Menampilkan sumbu x dan y
ax = plt.gca()
ax.spines['left'].set_position('zero')
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_position('zero')
ax.spines['bottom'].set_color('black')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Menentukan titik puncak dan sumbu simetri
x_puncak_13 = -b_13 / (2 * a_13)
y_puncak_13 = a_13 * x_puncak_13**2 + b_13 * x_puncak_13 + c_13
plt.plot(x_puncak_13, y_puncak_13, 'ro', markersize=8, label='Titik Puncak')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Grafik Persamaan Kuadrat')
plt.grid(True)
plt.legend()
plt.show()

# Menentukan posisi titik puncak
if a_13 > 0:
    if x_puncak_13 < 0:
        print("Titik Puncak berada di sebelah kiri sumbu y.")
    elif x_puncak_13 == 0:
        print("Titik Puncak berada pada sumbu y.")
    else:
        print("Titik Puncak berada di sebelah kanan sumbu y.")
else:
    if x_puncak_13 < 0:
        print("Titik Puncak berada di sebelah kanan sumbu y.")
    elif x_puncak_13 == 0:
        print("Titik Puncak berada pada sumbu y.")
    else:
        print("Titik Puncak berada di sebelah kiri sumbu y.")

# Menentukan kondisi parabola memotong sumbu
if b_13 == 0:
    if c_13 > 0:
        print("Parabola memotong sumbu y dengan nilai positif.")
    elif c_13 == 0:
        print("Parabola memotong sumbu y di titik pusat (0,0).")
    else:
        print("Parabola memotong sumbu y dengan nilai negatif.")
else:
    print("Parabola tidak memotong sumbu y.")

# Menentukan jenis akar persamaan kuadrat dari diskriminan
diskriminan_13 = b_13**2 - 4*a_13*c_13
if diskriminan_13 > 0:
    print("Persamaan kuadrat memiliki dua akar real yang berbeda.")
elif diskriminan_13 == 0:
    print("Persamaan kuadrat memiliki satu akar real.")
else:
    print("Persamaan kuadrat memiliki dua akar kompleks konjugat.")

# Menyusun persamaan kuadrat baru dari akar-akarnya
if akar1_13.imag == 0 and akar2_13.imag == 0:
    persamaan_kuadrat_baru_13 = f"{a_13}x^2 + {b_13}x + {c_13}"
    print("Persamaan Kuadrat Baru:", persamaan_kuadrat_baru_13)
else:
    print("Akar harus berupa bilangan real.")
# Out:
# Persamaan Kuadrat: 1x^2 + 1x + -6
# Titik Puncak berada di sebelah kiri sumbu y.
# Parabola tidak memotong sumbu y.
# Persamaan kuadrat memiliki dua akar real yang berbeda.
# Persamaan Kuadrat Baru: 1x^2 + 1x + -6

# %%
import matplotlib.pyplot as plt
import numpy as np

def persamaan_kuadrat_13(a_13, b_13, c_13):
    # Menghitung diskrimin_13an
    D_13 = b_13**2 - 4*a_13*c_13

    # Menentukan jenis akar
    if D_13 > 0:
        x1_13 = (-b_13 + np.sqrt(D_13)) / (2*a_13)
        x2_13 = (-b_13 - np.sqrt(D_13)) / (2*a_13)
        jenis_akar = "Akar real dan berbeda"
    elif D_13 == 0:
        x1_13 = -b_13 / (2*a_13)
        x2_13 = x1_13
        jenis_akar_13 = "Akar real kembar_13"
    else:
        x1_13 = complex(-b_13 / (2*a_13), np.sqrt(-D_13) / (2*a_13))
        x2_13 = complex(-b_13 / (2*a_13), -np.sqrt(-D_13) / (2*a_13))
        jenis_akar_13 = "Akar imajiner"

    # Menghitung titik puncak dan sumbu simetri
    x_puncak_13 = -b_13 / (2*a_13)
    y_puncak_13 = -D_13 / (4*a_13)

    # Menentukan posisi titik puncak
    if a_13 > 0:
        posisi_puncak_13 = "Titik puncak berada di bawah sumbu x"
    elif a_13 < 0:
        posisi_puncak_13 = "Titik puncak berada di atas sumbu x"
    else:
        posisi_puncak_13 = "Titik puncak berada pada sumbu x"

    # Menentukan kondisi potongan sumbu
    if a_13 > 0:
        kondisi_potongan_13 = "Potong sumbu y positif"
    elif a_13 < 0:
        kondisi_potongan_13 = "Potong sumbu y negatif"
    else:
        kondisi_potongan_13 = "Potong sumbu y di pusat (0,0)"

    # Menyusun persamaan kuadrat baru berdasarkan akar-akarnya
    a_baru_13 = a_13 / (x1_13 * x2_13)
    b_baru_13 = -a_baru_13 * (x1_13 + x2_13)
    c_baru_13 = a_baru_13 * x1_13 * x2_13

    # Menampilkan hasil
    print("Jenis Akar:", jenis_akar_13)
    print("Akar 1:", x1_13)
    print("Akar 2:", x2_13)
    print("Titik Puncak: ({}, {})".format(x_puncak_13, y_puncak_13))
    print("Posisi Titik Puncak:", posisi_puncak_13)
    print("Kondisi Potongan Sumbu:", kondisi_potongan_13)
    print("Persamaan Kuadrat Baru: {}x^2 + {}x + {}".format(a_baru_13, b_baru_13, c_baru_13))

    # Menampilkan grafik fungsi kuadrat
    x_13 = np.linspace(-10, 10, 100)
    y_13 = a_13*x_13**2 + b_13*x_13 + c_13

    plt.plot(x_13, y_13)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Grafik Fungsi Kuadrat')
    plt.grid(True)
    plt.axhline(y=0, color='k')
    plt.axvline(x=0, color='k')
    plt.show()

# Input koefisien persamaan kuadrat
a_13 = float(input("Masukkan koefisien a: "))
b_13 = float(input("Masukkan koefisien b: "))
c_13 = float(input("Masukkan koefisien c: "))

# Memanggil fungsi persamaan_kuadrat
persamaan_kuadrat_13(a_13, b_13, c_13)
# Out:
# Masukkan koefisien a:  1
# Masukkan koefisien b:  2
# Masukkan koefisien c:  3
# Jenis Akar: Akar imajiner
# Akar 1: (-1+1.4142135623730951j)
# Akar 2: (-1-1.4142135623730951j)
# Titik Puncak: (-1.0, 2.0)
# Posisi Titik Puncak: Titik puncak berada di bawah sumbu x
# Kondisi Potongan Sumbu: Potong sumbu y positif
# Persamaan Kuadrat Baru: (0.33333333333333326+0j)x^2 + (0.6666666666666665+0j)x + (0.9999999999999999+0j)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cmath

# Nilai a tidak boleh sama dengan nol
def cek_a_13():
    while True:
        a_13 = float(input("Masukkan koefisien a: "))
        if a_13 != 0:
            return a_13
        print("Nilai a tidak boleh sama dengan 0 yaaa... Silakan masukkan nilai a kembali.")

# Meminta pengguna untuk menginput koefisien a, b, c
def menerima_input_13():
    a_13 = cek_a_13()
    b_13 = float(input("Masukkan koefisien b: "))
    c_13 = float(input("Masukkan koefisien c: "))
    return a_13, b_13, c_13

# Mencari titik potong dan menentukan arah grafik
def grafik_hasil_13(a_13, b_13, c_13, x1_13, x2_13):
    D_13 = diskriminan_13(a_13, b_13, c_13)
    tp_x_13 = -b_13 / (2*a_13)
    tp_y_13 = -D_13 / (4*a_13)
    print(f"Koordinat titik puncak adalah ({tp_x_13:.2f}, {tp_y_13:.2f})")
    if a_13 < 0:
        print("Grafik akan terbuka ke bawah")
    else:
        print("Grafik akan terbuka ke atas")
        
# Menghitung diskriminan
def diskriminan_13(a_13, b_13, c_13):
    return b_13**2 - 4*a_13*c_13

# Mencari solusi persamaan kuadrat
def solusi_kuadrat_13(a_13, b_13, c_13):
    D_13 = diskriminan_13(a_13, b_13, c_13)
    x1_13 = (-b_13 + cmath.sqrt(D_13)) / (2*a_13)
    x2_13 = (-b_13 - cmath.sqrt(D_13)) / (2*a_13)
    return x1_13, x2_13, D_13

# Menghitung sumbu simetri        
def sumbu_simetri_13 (b_13, a_13):
    return -b_13/2*a_13

# Solusi persamaan kuadrat
def tampilkan_solusi_13(x1_13, x2_13, D_13):
    if x1_13 == x2_13:
        print(f"Solusi dari persamaan kuadrat tersebut adalah x1 = x2 = {x1_13:.2f}")
    else:
        print(f"Solusi dari persamaan kuadrat tersebut adalah x1 = {x1_13:.2f}, dan x2 = {x2_13:.2f}")
    
    if D_13 == 0:
        print("Persamaan kuadrat memiliki akar kembar")
        print(f"Memotong tepat satu titik di sumbu x, yaitu di titik ({x1_13.real:.2f}, 0)")
    elif D_13 < 0:
        print("Persamaan kuadrat memiliki akar imajiner")
        print("Tidak memotong sumbu x")
    else:
        print("Persamaan kuadrat memiliki akar real berbeda")
        print(f"Memotong sumbu x di dua titik, yaitu titik ({x1_13.real:.2f}, 0) dan ({x2_13.real:.2f}, 0)")
        
    
    x_13 = np.linspace(- 10, 10, 100)
    y_13 = a_13*x_13**2 + b_13*x_13 + c_13

    plt.figure(figsize=(8, 8))
    plt.plot(x_13, y_13, label=f'{a_13}x^2 + {b_13}x + {c_13} = 0', color='blue')
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Grafik Persamaan Kuadrat')
    plt.show()

# Titik puncak persamaan kuadrat berada di kuadran 
def posisi_tp_13(a_13, b_13, c_13, x1_13, x2_13):
    D_13 = diskriminan_13(a_13, b_13, c_13)
    tp_x_13 = -b_13 / (2*a_13)
    tp_y_13 = -D_13 / (4*a_13)
    
    if tp_x_13 >= 0  and tp_y_13 >= 0 :
        print ("Posisi titik puncak berada di kuadran I")
    elif tp_x_13 <= 0 and tp_y_13 >= 0 :
        print ("Posisi titik puncak  berada di kuadran II")
    elif tp_x_13 <= 0 and tp_y_13 <= 0 :
        print ("Posisi titik puncak berada di kuadran III")
    elif tp_x_13 >= 0 and tp_y_13 <= 0 :
        print ("Posisi titik puncak berada di kuadran IV")
    else :
        print ("Posisi titik puncak berada di tepat di titik pusat koordinat")

a_13, b_13, c_13 = menerima_input_13()
print(f"Persamaan yang kamu masukkan adalah {a_13}x^2 + {b_13}x + {c_13} = 0")

x1_13, x2_13, D_13 = solusi_kuadrat_13(a_13, b_13, c_13)
tampilkan_solusi_13(x1_13, x2_13, D_13)

simetri_13 = sumbu_simetri_13(b_13, a_13)
print(f"Sumbu simetri pada persamaan kuadrat ini adalah x = {simetri_13}")

posisi_tp_13(a_13, b_13, c_13, x1_13, x2_13)

grafik_hasil_13(a_13, b_13, c_13, x1_13, x2_13)
# Out:
# Masukkan koefisien a:  3
# Masukkan koefisien b:  4
# Masukkan koefisien c:  6
# Persamaan yang kamu masukkan adalah 3.0x^2 + 4.0x + 6.0 = 0
# Solusi dari persamaan kuadrat tersebut adalah x1 = -0.67+1.25j, dan x2 = -0.67-1.25j
# Persamaan kuadrat memiliki akar imajiner
# Tidak memotong sumbu x
# Sumbu simetri pada persamaan kuadrat ini adalah x = -6.0
# Posisi titik puncak  berada di kuadran II
# Koordinat titik puncak adalah (-0.67, 4.67)
# Grafik akan terbuka ke atas

# %%
import matplotlib.pyplot as plt
import numpy as np

def cari_persamaan_kuadrat_13(a_13, b_13, c_13):
    diskriminan_13 = b_13**2 - 4*a_13*c_13

    if diskriminan_13 > 0:
        x1_13 = (-b_13 + np.sqrt(diskriminan_13)) / (2*a_13)
        x2_13 = (-b_13 - np.sqrt(diskriminan_13)) / (2*a_13)
        return x1_13, x2_13
    elif diskriminan_13 == 0:
        x_13 = -b_13 / (2*a_13)
        return x_13
    else:
        return None

def gambar_grafik_13(a_13, b_13, c_13):
    x_13 = np.linspace(-10, 10, 400)
    y_13 = a_13*x_13**2 + b_13*x_13 + c_13

    plt.plot(x_13, y_13)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("Grafik Persamaan Kuadrat")
    plt.grid(True)
    plt.show()

def titik_puncak_13(a_13, b_13, c_13):
    tp_x_13 = -b_13 / (2*a_13)
    tp_y_13 = a_13*tp_x_13**2 + b_13*tp_x_13 + c_13

    return tp_x_13, tp_y_13

def sumbu_simetri_13(a_13, b_13, c_13):
    tp_x_13 = -b_13 / (2*a_13)

    return tp_x_13

def posisi_puncak_13(a_13):
    if a_13 > 0:
        return "Puncak berada di atas sumbu y"
    elif a_13 < 0:
        return "Puncak berada di bawah sumbu y"
    else:
        return "Puncak berada pada sumbu y"

def kondisi_parabola_13(a):
    if a_13 > 0:
        return "Parabola memotong sumbu y positif"
    elif a_13 < 0:
        return "Parabola memotong sumbu y negatif"
    else:
        return "Parabola memotong sumbu y di pusat y"

def persamaan_kuadrat_dari_akar_13(x1_13, x2_13):
    a_13 = 1
    b_13 = -(x1 + x2)
    c_13 = x1 * x2

    return a_13, b_13, c_13

# Main program
a_13 = float(input("Masukkan koefisien a: "))
b_13 = float(input("Masukkan koefisien b: "))
c_13 = float(input("Masukkan koefisien c: "))

akar_13 = cari_persamaan_kuadrat_13(a_13, b_13, c_13)
if akar_13 is not None:
    print("Akar persamaan kuadrat:", akar_13)
    baru_a_13, baru_b_13, baru_c_13 = persamaan_kuadrat_dari_akar_13(akar_13)
    print("Persamaan kuadrat baru:", baru_a_13, "x^2 +", baru_b_13, "x +", baru_c_13)
else:
    print("Persamaan kuadrat tidak memiliki akar real")

gambar_grafik_13(a_13, b_13, c_13)

puncak_13 = titik_puncak_13(a_13, b_13, c_13)
print("Titik puncak:", puncak_13)

sumbu_13 = sumbu_simetri_13(a_13, b_13, c_13)
print("Sumbu simetri:", sumbu_13)

posisi_13 = posisi_puncak_13(a_13)
print("Posisi puncak:", posisi_13)

kondisi_13 = kondisi_parabola_13(a_13)
print("Kondisi parabola:", kondisi_13)
# Out:
# Masukkan koefisien a:  1
# Masukkan koefisien b:  2
# Masukkan koefisien c:  3
# Persamaan kuadrat tidak memiliki akar real
# Titik puncak: (-1.0, 2.0)
# Sumbu simetri: -1.0
# Posisi puncak: Puncak berada di atas sumbu y
# Kondisi parabola: Parabola memotong sumbu y positif
