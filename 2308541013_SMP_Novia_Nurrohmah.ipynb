# %%
#Soal
print("Diketahui x memenuhi:")
print(f"x**2 + x - 1 = 0\n")
print("Tentukan nilai n yang memenuhi:")
print(f"x**2024 - x**2025 = (x * (1 - x))**n\n")
print(f"Penyelesaian:")

#Mencari nilai x dengan menggunakan rumus ABC
import math
def cari_nilai_x_13():
    #nilai a,b,c
    a_13 = 1
    b_13 = 1
    c_13 = -1
    # Menggunakan rumus ABC untuk mencari nilai x
    D_13 = math.sqrt(b_13**2 - 4*a_13*c_13)
    x1_13 = (-b_13 + D_13) / (2*a_13)
    x2_13 = (-b_13 - D_13) / (2*a_13)
    return x1, x2

x1_13, x2_13 = cari_nilai_x_13()
print(f"Solusi nilai x adalah x1 = {x1_13}, x2 = {x2_13}")

#Mencari nilai n menggunakan logaritma
import math
def cari_nilai_n_13(x):
    basis_13 = x_13 * (1 - x_13) 

    # Menghitung logaritma dengan basis yang sudah ditentukan
    def log_b_13(nilai_13, basis_13):
        return math.log(abs(nilai_13)) / math.log(abs(basis_13))
    # Menghitung nilai n
    n_13 = (2024 * log_b_13(x_13, basis_13) + log_b_13(1 - x_13, basis_13)) / (log_b_13(x_13, basis_13) + log_b_13(1 - x_13, basis_13))
    return n_13

# Menggunakan solusi x dari persamaan kuadrat sebelumnya
x_13 = float(input("Masukkan nilai x: "))

solusi_n_13 = cari_nilai_n_13(x)
print(f"Solusi nilai n saat x = {x_13} adalah n = {solusi_n_13}")
# Out:
# Diketahui x memenuhi:
# x**2 + x - 1 = 0
#
# Tentukan nilai n yang memenuhi:
# x**2024 - x**2025 = (x * (1 - x))**n
#
# Penyelesaian:
# Solusi nilai x adalah x1 = 0.6180339887498949, x2 = -1.618033988749895
# Masukkan nilai x:  0.6180339887498949
# Solusi nilai n saat x = 0.6180339887498949 adalah n = 675.3333333333331

# %%
#Soal
print("Diketahui x memenuhi:")
print(f"x**2 + x - 1 = 0\n")
print("Tentukan nilai n yang memenuhi:")
print(f"x**2024 - x**2025 = (x * (1 - x))**n\n")
print(f"Penyelesaian:")

#Mencari nilai x dengan menggunakan rumus ABC
import math
def cari_akar_13(a_13, b_13, c_13):
    D_13 = b_13**2 - 4*a_13*c_13

    if D_13 > 0:
        x1_13 = (-b_13 + math.sqrt(D_13)) / (2*a_13)
        x2_13 = (-b_13 - math.sqrt(D_13)) / (2*a_13)
        return x1_13, x2_13
    elif D_13 == 0:
        x_13 = -b_13 / (2*a_13)
        return x_13
    else:
        return None
    
    #Nilai a,b,c
    a_13 = 1
    b_13 = 1
    c_13 = -1

hasil_akar_13 = cari_akar_13(a_13, b_13, c_13)

if hasil_akar_13 is not None:
    if type(hasil_akar_13) == tuple:
        x1_13, x2_13 = hasil_akar_13
        print("Akar persamaan kuadratnya ada dua yaitu x1 = ", x1_13, "dan x2 = ", x2_13)
    else:
        x_13 = hasil_akar_13
        print("Akar persamaan kuadratnya adalah", x_13)
else:
    print("Persamaan kuadrat tidak memiliki akar real")

#Mencari nilai n menggunakan logaritma    
import math
def cari_nilai_n_13(x_13):
    basis_13 = x_13 * (1 - x_13)
    # Menghitung logaritma dengan basis tertentu
    def log_b_13(nilai_13, basis_13):
        return math.log(abs(nilai_13)) / math.log(abs(basis_13))
    # Menghitung nilai n
    n_13 = (2024 * log_b_13(x_13, basis_13) + log_b_13(1 - x_13, basis_13)) / (log_b_13(x_13, basis_13) + log_b_13(1 - x_13, basis_13))
    return n_13

# Menggunakan solusi x dari hasil persamaana kuadrat sebelumnya
x_13 = float(input("Masukkan nilai x: "))

solusi_n_13 = cari_nilai_n_13(x_13)
print(f"Solusi nilai n saat x = {x_13} adalah n = {solusi_n_13}")
# Out:
# Diketahui x memenuhi:
# x**2 + x - 1 = 0
#
# Tentukan nilai n yang memenuhi:
# x**2024 - x**2025 = (x * (1 - x))**n
#
# Penyelesaian:
# Akar persamaan kuadratnya ada dua yaitu x1 =  0.6180339887498949 dan x2 =  -1.618033988749895
# Masukkan nilai x:  -1.618033988749895
# Solusi nilai n saat x = -1.618033988749895 adalah n = 675.3333333333334
